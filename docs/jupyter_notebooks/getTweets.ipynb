# %% [markdown]
# # Get Tweets with Tweepy

# %%
# Import Twitter API Token
import logging
import sys
sys.path.append('../../../sentiment/')
from config import Config
api = Config().create_api("auth1")
logging.basicConfig(level=logging.INFO)
logger = logging.getLogger()

# %%
import tweepy

# Search for #tsla
search_words = "#tsla -filter:retweets"
search_words = "#btc -filter:retweets"

# counter=1
# # Cursor searches are for Pagination: Retrieve more data than can be returned in a single response
# for tweet in tweepy.Cursor(api.search_tweets,tweet_mode='extended',q=search_words,lang="en").items():
#     print("Tweet Downloaded: ",counter)
#     print(tweet.full_text+"\n")
#     counter+=1
#     if counter > 5:
#         break
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /Users/marvinottersberg/Documents/GitHub/sentiment/docs/jupyter_notebooks/getTweets.ipynb Cell 3 in <cell line: 16>()
#       <a href='vscode-notebook-cell:/Users/marvinottersberg/Documents/GitHub/sentiment/docs/jupyter_notebooks/getTweets.ipynb#ch0000002?line=4'>5</a> search_words = "#btc -filter:retweets"
#       <a href='vscode-notebook-cell:/Users/marvinottersberg/Documents/GitHub/sentiment/docs/jupyter_notebooks/getTweets.ipynb#ch0000002?line=6'>7</a> # counter=1
#       <a href='vscode-notebook-cell:/Users/marvinottersberg/Documents/GitHub/sentiment/docs/jupyter_notebooks/getTweets.ipynb#ch0000002?line=7'>8</a> # # Cursor searches are for Pagination: Retrieve more data than can be returned in a single response
#       <a href='vscode-notebook-cell:/Users/marvinottersberg/Documents/GitHub/sentiment/docs/jupyter_notebooks/getTweets.ipynb#ch0000002?line=8'>9</a> # for tweet in tweepy.Cursor(api.search_tweets,tweet_mode='extended',q=search_words,lang="en").items():
#    (...)
#      <a href='vscode-notebook-cell:/Users/marvinottersberg/Documents/GitHub/sentiment/docs/jupyter_notebooks/getTweets.ipynb#ch0000002?line=12'>13</a> #     if counter > 5:
#      <a href='vscode-notebook-cell:/Users/marvinottersberg/Documents/GitHub/sentiment/docs/jupyter_notebooks/getTweets.ipynb#ch0000002?line=13'>14</a> #         break
# ---> <a href='vscode-notebook-cell:/Users/marvinottersberg/Documents/GitHub/sentiment/docs/jupyter_notebooks/getTweets.ipynb#ch0000002?line=15'>16</a> for tweet in tweepy.Cursor(api.search_full_archive,tweet_mode='extended',q=search_words,lang="en").items():
#      <a href='vscode-notebook-cell:/Users/marvinottersberg/Documents/GitHub/sentiment/docs/jupyter_notebooks/getTweets.ipynb#ch0000002?line=17'>18</a>     print(tweet)
#
# File ~/opt/anaconda3/envs/dontbesentimental/lib/python3.9/site-packages/tweepy/cursor.py:86, in BaseIterator.__next__(self)
#      85 def __next__(self):
# ---> 86     return self.next()
#
# File ~/opt/anaconda3/envs/dontbesentimental/lib/python3.9/site-packages/tweepy/cursor.py:286, in ItemIterator.next(self)
#     283     raise StopIteration
#     284 if self.current_page is None or self.page_index == len(self.current_page) - 1:
#     285     # Reached end of current page, get the next page...
# --> 286     self.current_page = next(self.page_iterator)
#     287     while len(self.current_page) == 0:
#     288         self.current_page = next(self.page_iterator)
#
# File ~/opt/anaconda3/envs/dontbesentimental/lib/python3.9/site-packages/tweepy/cursor.py:86, in BaseIterator.__next__(self)
#      85 def __next__(self):
# ---> 86     return self.next()
#
# File ~/opt/anaconda3/envs/dontbesentimental/lib/python3.9/site-packages/tweepy/cursor.py:260, in NextIterator.next(self)
#     258 if self.next_token == -1 or self.page_count >= self.limit:
#     259     raise StopIteration
# --> 260 data = self.method(next=self.next_token, return_cursors=True, *self.args, **self.kwargs)
#     261 self.page_count += 1
#     262 if isinstance(data, tuple):
#
# File ~/opt/anaconda3/envs/dontbesentimental/lib/python3.9/site-packages/tweepy/api.py:33, in pagination.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#      31 @functools.wraps(method)
#      32 def wrapper(*args, **kwargs):
# ---> 33     return method(*args, **kwargs)
#
# File ~/opt/anaconda3/envs/dontbesentimental/lib/python3.9/site-packages/tweepy/api.py:46, in payload.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#      44 kwargs['payload_list'] = payload_list
#      45 kwargs['payload_type'] = payload_type
# ---> 46 return method(*args, **kwargs)
#
# TypeError: search_full_archive() missing 2 required positional arguments: 'label' and 'query'

# %% [markdown]
# ## Small Test to tweet with Tweepy from my User(@moerv9) and see if I can scrape that Tweet
#
#     api.update_status("I want to buy #tsla")
# <img src="../../img/moerv9_tweet.png" alt="Moerv9 Twitter Profile" style="width:550px;height:280px;">
#
# Scraping with the exact Words but it is also found when only searching for '#tsla':
#
#     search_words = "I want to buy #tsla -filter:retweets"
#     posts = tweepy.Cursor(api.search_tweets,tweet_mode="extended", q=search_words,lang="en").items(50)
#
# <img src="../../img/moerv9_tweet_with_tweepy.png" alt="Moerv9 Tweet with Tweepy" style="width:940px;height:280px;">

# %% [markdown]
# ## Exporting a Dataset

# %%
import pandas as pd
import tweepy

# Get Tweets
search_words = " #tsla -filter:retweets"
posts = tweepy.Cursor(api.search_tweets,tweet_mode="extended", q=search_words,lang="en").items(50)

# Setup Dataframe
pd.set_option("display.max_columns",80)

df = pd.DataFrame([[
    tweet.full_text, 
    tweet.user.followers_count,
    tweet.created_at,
    tweet.retweet_count,
    tweet.user.verified,
    tweet.user.created_at,
    tweet.entities["hashtags"]
    ] for tweet in posts], columns=["Tweet","Follower","Date of Tweet","Retweets","Verified","User since","Hashtags"])

# Function to Clean the Datetime Format (Making it timezone unaware and getting rid of the timestamps)
from datetime import datetime

def cleanDates(date):
    date = date.tz_localize(None)
    date = datetime.strftime(date,"%d-%m-%Y %H:%M")
    return date

# Apply function to Columns with Dates
df["Date of Tweet"] = df["Date of Tweet"].apply(cleanDates)
df["User since"] = df["User since"].apply(cleanDates) 

# Write to Excel
#df.to_json("tweet_dataset.json")
#df.to_excel("../datasets/tweet_dataset.xlsx")
df.head(8)
# Out:
#                                                Tweet  Follower  \
# 0  We wish you more Bitcoins and...healthy fruits...      8514
# 1  @elonmusk @tesla must see 👇\n\n#tesla #tsla\n\...        57
# 2  TLRY over $20 than $50 soon next week 💯 💰 🍀 🚀 ...       460
# 3  @TeslaAndDoge I don’t see how #pltr can be the...         8
# 4  @GordonJohnson19 JUST CHANGED HIS RATING TO BU...       224
# 5  Now it‘s official that #TSLA is a government p...        38
# 6  Here’s a group of stocks that have potential u...       144
# 7  WTF is #TSLA down -24% \npre-market ????\n\nAn...       329
#
#       Date of Tweet  Retweets  Verified        User since  \
# 0  01-04-2022 09:23         0     False  20-05-2018 10:40
# 1  01-04-2022 09:16         0     False  13-09-2021 11:07
# 2  01-04-2022 09:02         1     False  11-01-2021 09:26
# 3  01-04-2022 08:22         0     False  27-12-2018 21:52
# 4  01-04-2022 08:20         0     False  29-06-2011 20:11
# 5  01-04-2022 08:19         0     False  03-02-2009 10:18
# 6  01-04-2022 08:02         0     False  14-01-2020 01:27
# 7  01-04-2022 07:57         0     False  03-01-2011 23:47
#
#                                             Hashtags
# 0  [{'text': 'newmonth', 'indices': [59, 68]}, {'...
# 1  [{'text': 'tesla', 'indices': [29, 35]}, {'tex...
# 2  [{'text': 'Shortsqueeze', 'indices': [46, 59]}...
# 3  [{'text': 'pltr', 'indices': [30, 35]}, {'text...
# 4            [{'text': 'TSLA', 'indices': [48, 53]}]
# 5            [{'text': 'TSLA', 'indices': [23, 28]}]
# 6  [{'text': 'GME', 'indices': [101, 105]}, {'tex...
# 7  [{'text': 'TSLA', 'indices': [7, 12]}, {'text'...

# %%
#TODO: Make it to a class to be functional and callable! make a backtest and publish as usable function to gh pages / streamlit?
