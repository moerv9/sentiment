# %% [markdown]
# # Get Tweets with Tweepy

# %%
# Import Twitter API Token
import sys
sys.path.append('../../api/')
import keys

API_KEY, API_SECRET, BEARER_TOKEN,ACCESS_TOKEN,ACCESS_SECRET = keys.getKeys()

# %%
import tweepy

# Init Tweepy
auth = tweepy.OAuth1UserHandler(
    API_KEY, API_SECRET, ACCESS_TOKEN, ACCESS_SECRET
)
api = tweepy.API(auth, wait_on_rate_limit=True)

# Search for #tsla
search_words = "#tsla -filter:retweets"
counter=1
for tweet in tweepy.Cursor(api.search_tweets,tweet_mode='extended',q=search_words,lang="en").items():
    print("Tweet Downloaded: ",counter)
    print(tweet.full_text+"\n")
    counter+=1
    if counter > 5:
        break
# Out:
# Tweet Downloaded:  1
# ⁦@POTUS⁩ ⁦@VP⁩ ⁦@SenSanders⁩ ⁦@SenWarren⁩ ⁦so this is how good jobs are created?  That is inly if your employer is more ammoral than the ⁦@UAW⁩.  $TSLA #TSLA ⁦@elonmusk⁩ IS BETTER THAN THE UNIONS🚀🚀🚀 https://t.co/46WHJOUYoz
#
# Tweet Downloaded:  2
# Gym ✅
# $1,171.25 from the market today✅
# #LetsRide #gym #stocks #TSLA
#
# Tweet Downloaded:  3
# love Sara Eisen quote today on #cnbc, #TSLA is up 8% this week and it’s only Tuesday. Love it!
#
# Tweet Downloaded:  4
# Not everyday you get 10% in 3 mins on a big cap #amc #gme #tsla #hymc #hood #daytrading https://t.co/towJiMmaMy
#
# Tweet Downloaded:  5
# @userofintellect @TOFIQFAZL Rather worrying to see #TSLA following #AMC movements today.

# %%
# Export as Dataset
import pandas as pd

# Get Tweets
posts = tweepy.Cursor(api.search_tweets,tweet_mode="extended", q=search_words,lang="en").items(50)

# Setup Dataframe
pd.set_option("display.max_columns",80)
df = pd.DataFrame([[
    tweet.full_text, 
    tweet.user.followers_count,
    tweet.created_at,
    tweet.retweet_count,
    tweet.user.verified,
    tweet.user.created_at,
    tweet.entities["hashtags"]
    ] for tweet in posts], columns=["Tweet","Follower","Date of Tweet","Retweets","Verified","User since","Hashtags"])

# Function to Clean the Datetime Format (Making it timezone unaware and getting rid of the timestamps)
from datetime import datetime
def cleanDates(date):
    date = date.tz_localize(None)
    date = datetime.strftime(date,"%Y-%m-%d")
    return date

# Apply function to Columns with Dates
df["Date of Tweet"] = df["Date of Tweet"].apply(cleanDates)
df["User since"] = df["User since"].apply(cleanDates) 

# Write to Excel
#df.to_json("tweet_dataset.json")
df.to_excel("tweet_dataset.xlsx")
df
# Out:
#                                                 Tweet  Follower Date of Tweet  \
# 0   ⁦@POTUS⁩ ⁦@VP⁩ ⁦@SenSanders⁩ ⁦@SenWarren⁩ ⁦so ...         9    2022-03-29
# 1   Gym ✅\n$1,171.25 from the market today✅\n#Lets...        31    2022-03-29
# 6             [{'text': 'TSLA', 'indices': [87, 92]}]
# 7   [{'text': 'CanadaNickel', 'indices': [152, 165...
# 8           [{'text': 'TSLA', 'indices': [198, 203]}]
# 9             [{'text': 'tsla', 'indices': [36, 41]}]
# 10            [{'text': 'TSLA', 'indices': [29, 34]}]
# 11            [{'text': 'TSLA', 'indices': [25, 30]}]
# 12              [{'text': 'TSLA', 'indices': [0, 5]}]
# 13            [{'text': 'TSLA', 'indices': [30, 35]}]
# 14  [{'text': 'tsla', 'indices': [103, 108]}, {'te...
# 15  [{'text': 'AAPL', 'indices': [111, 116]}, {'te...
# 16  [{'text': 'TSLA', 'indices': [173, 178]}, {'te...
# 17  [{'text': 'TSLA', 'indices': [0, 5]}, {'text':...
# 18  [{'text': 'TSLA', 'indices': [9, 14]}, {'text'...
# 19  [{'text': 'tesla', 'indices': [33, 39]}, {'tex...
# 20            [{'text': 'TSLA', 'indices': [31, 36]}]
# 21  [{'text': 'ev', 'indices': [24, 27]}, {'text':...
# 22  [{'text': 'ev', 'indices': [84, 87]}, {'text':...
# 23            [{'text': 'TSLA', 'indices': [28, 33]}]
# 24  [{'text': 'TSLA', 'indices': [218, 223]}, {'te...
# 25  [{'text': 'TSLA', 'indices': [111, 116]}, {'te...
# 26            [{'text': 'TSLA', 'indices': [79, 84]}]
# 27  [{'text': 'PLTR', 'indices': [29, 34]}, {'text...
# 28  [{'text': 'HBAR', 'indices': [17, 22]}, {'text...
# 29  [{'text': 'Tesla', 'indices': [26, 32]}, {'tex...
# 30            [{'text': 'TSLA', 'indices': [51, 56]}]
# 31  [{'text': 'Webull', 'indices': [85, 92]}, {'te...
# 32  [{'text': 'EVs', 'indices': [31, 35]}, {'text'...
# 33  [{'text': 'TSLA', 'indices': [94, 99]}, {'text...
# 34  [{'text': 'options', 'indices': [78, 86]}, {'t...
# 35  [{'text': 'Musk', 'indices': [75, 80]}, {'text...
# 36  [{'text': 'Musk', 'indices': [75, 80]}, {'text...
# 37  [{'text': 'Musk', 'indices': [111, 116]}, {'te...
# 38  [{'text': 'Musk', 'indices': [84, 89]}, {'text...
# 39  [{'text': 'Musk', 'indices': [81, 86]}, {'text...
# 40  [{'text': 'tesla', 'indices': [26, 32]}, {'tex...
# 41             [{'text': 'tsla', 'indices': [7, 12]}]
# 42            [{'text': 'TSLA', 'indices': [18, 23]}]
# 43            [{'text': 'TSLA', 'indices': [22, 27]}]
# 44            [{'text': 'TSLA', 'indices': [11, 16]}]
# 45  [{'text': 'doge', 'indices': [25, 30]}, {'text...
# 46            [{'text': 'TSLA', 'indices': [17, 22]}]
# 47            [{'text': 'TSLA', 'indices': [18, 23]}]
# 48          [{'text': 'TSLA', 'indices': [152, 157]}]
# 49          [{'text': 'TSLA', 'indices': [163, 168]}]
